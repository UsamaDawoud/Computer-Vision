# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
pic = Image.open('IMG-20181229-WA0023.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (960, 1280, 3)

# %%
# so there is 3 channels each (960 * 1280) for Red , Green & Blue

# %%
plt.imshow(pic_arr);

# %%
pic_red = pic_arr.copy()
plt.imshow(pic_red);

# %%
# R G B 
plt.imshow(pic_red[: , : , 0])

# %%
# the red channel values 0 - 255
plt.imshow(pic_arr[: , : , 0],cmap='gray')

# %%
# the Green channel 
plt.imshow(pic_arr[: , : , 1]);

# %%
# the Green channel values 0 - 255
plt.imshow(pic_arr[: , : , 1],cmap='gray');

# %%
# the Blue channel values 0 - 255
plt.imshow(pic_arr[: , : , 2],cmap='gray');

# %%
# to get the red version of the image ( set G & B colors to zeros)
pic_red[: , : , 1]=0
pic_red[: , : , 2]=0
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (960, 1280, 3)

# %%
# there is no dimention change , only the values of Green & Blue colors chennels become zeros

# %%
pic_arr[: , : , 0].shape
# Out:
# (960, 1280)

# %%
pic_arr[: , : , 1].shape
# Out:
# (960, 1280)

# %%
pic_arr[: , : , 2].shape
# Out:
# (960, 1280)

# %%
# all channel still exist
